# %% [markdown]
# Missing Values problem

# %%
import geopandas as gpd

# %%
world=gpd.read_file((gpd.datasets.get_path('naturalearth_lowres')))
# Out:
# C:\Users\Bibek\AppData\Local\Temp\ipykernel_21068\745040763.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world=gpd.read_file((gpd.datasets.get_path('naturalearth_lowres')))

# %%
world.tail()
# Out:
#         pop_est      continent                 name iso_a3  gdp_md_est  \
# 172   6944975.0         Europe               Serbia    SRB       51475
# 173    622137.0         Europe           Montenegro    MNE        5542
# 174   1794248.0         Europe               Kosovo    -99        7926
# 175   1394973.0  North America  Trinidad and Tobago    TTO       24269
# 176  11062113.0         Africa             S. Sudan    SSD       11998
#
#                                               geometry
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...

# %%
world.isnull().sum()
# Out:
# pop_est       0
# continent     0
# name          0
# iso_a3        0
# gdp_md_est    0
# geometry      0
# dtype: int64

# %% [markdown]
# no missing value detected

# %% [markdown]
# **Feature Engineering**

# %%
world['centroid_x']=world.centroid.x
world['centroid_y']=world.centroid.y
# Out:
# C:\Users\Bibek\AppData\Local\Temp\ipykernel_21068\1184392000.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world['centroid_x']=world.centroid.x
# C:\Users\Bibek\AppData\Local\Temp\ipykernel_21068\1184392000.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world['centroid_y']=world.centroid.y

# %%
world.tail()
# Out:
#         pop_est      continent                 name iso_a3  gdp_md_est  \
# 172   6944975.0         Europe               Serbia    SRB       51475
# 173    622137.0         Europe           Montenegro    MNE        5542
# 174   1794248.0         Europe               Kosovo    -99        7926
# 175   1394973.0  North America  Trinidad and Tobago    TTO       24269
# 176  11062113.0         Africa             S. Sudan    SSD       11998
#
#                                               geometry  centroid_xx  \
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...    20.819652
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...    19.286182
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...    20.895356
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...   -61.330367
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...    30.198618
#
#      centroid_yy  centroid_x  centroid_y
# 172    44.233037   20.819652   44.233037
# 173    42.789040   19.286182   42.789040
# ...

# %%
world["area"]=world.geometry.area
# Out:
# C:\Users\Bibek\AppData\Local\Temp\ipykernel_21068\2227828872.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world["area"]=world.geometry.area

# %%
world.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry  centroid_xx  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...   163.853165
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...    34.752990
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...   -12.137831
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...   -98.142381
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  -112.599436
#
#    centroid_yy  centroid_x  centroid_y         area
# 0   -17.316309  163.853165  -17.316309     1.639511
# ...

# %%
world['buffer']=world.geometry.buffer(1.0)
# Out:
# C:\Users\Bibek\AppData\Local\Temp\ipykernel_21068\2230477610.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   world['buffer']=world.geometry.buffer(1.0)

# %%
world.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry  centroid_xx  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...   163.853165
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...    34.752990
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...   -12.137831
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...   -98.142381
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  -112.599436
#
#    centroid_yy  centroid_x  centroid_y         area  \
# 0   -17.316309  163.853165  -17.316309     1.639511
# ...

# %%
world["simplyfying_geometry"]=world.geometry.simplify(tolerance=0.01)

# %%
world.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry  centroid_xx  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...   163.853165
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...    34.752990
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...   -12.137831
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...   -98.142381
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  -112.599436
#
#    centroid_yy  centroid_x  centroid_y         area  \
# 0   -17.316309  163.853165  -17.316309     1.639511
# ...

# %%
world['code of C']=world['continent'].astype('category').cat.codes

# %%
world
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
# ...
