# %% [markdown]
# **filling the missing one**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"D:\My Projects\ML\Data preprocessing for Machine Learning\dataset_nepali.csv")

# %%
dataset.head(50)
# Out:
#     ID               Name   Age    District  Salary_NPR  \
# 0    1         Vidur Hans  54.0     Pokhara     56737.0
# 1    2    Zeeshan Kapadia  41.0   Bhaktapur    137972.0
# 2    3        Kartik Sane  46.0     Chitwan    117427.0
# 3    4        Divij Bobal  38.0     Chitwan     44124.0
# 4    5    Uthkarsh Butala  31.0    Lalitpur     90102.0
# 5    6       Samar Thaker  39.0    Lalitpur     22196.0
# 6    7        Kaira Walla  20.0      Butwal     81527.0
# 7    8      Baiju Krishna  40.0   Nepalgunj    116651.0
# 8    9          Ira Karpe   NaN   Kathmandu    135477.0
# 9   10       Yuvraj  Dhar  29.0   Kathmandu    105395.0
# 10  11   Azad Subramaniam  51.0  Biratnagar     31345.0
# 11  12        Vedika Mane  58.0  Biratnagar    144544.0
# 12  13  Devansh Chaudhary  41.0     Chitwan     54077.0
# 13  14      Samaira Lanka   NaN     Chitwan     86400.0
# 14  15        Ranbir Bala  51.0     Pokhara     32055.0
# 15  16         Yuvaan Ben  46.0     Pokhara    123693.0
# ...

# %%
# dataset.fillna(10).head(4)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Name              1000 non-null   object
#  2   Age               970 non-null    float64
#  3   District          959 non-null    object
#  4   Salary_NPR        970 non-null    float64
#  5   Department        971 non-null    object
#  6   Experience_Years  966 non-null    float64
#  7   Rating            962 non-null    float64
#  8   Join_Date         1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
# dataset.fillna(method='bfill',axis=1).head(50)

# %%
dataset["District"].mode()[0]
# Out:
# 'Bhaktapur'

# %%
dataset["District"].fillna(dataset["District"].mode()[0])
# Out:
# 0         Pokhara
# 1       Bhaktapur
# 2         Chitwan
# 3         Chitwan
# 4        Lalitpur
#           ...
# 995     Kathmandu
# 996       Pokhara
# 997     Nepalgunj
# 998     Kathmandu
# 999    Biratnagar
# Name: District, Length: 1000, dtype: object

# %%
dataset.select_dtypes(include=['object']).isnull().sum()
# Out:
# Name           0
# District      41
# Department    29
# Join_Date      0
# dtype: int64

# %%
dataset["Department"].mode()[0]
# Out:
# 'Finance'

# %%
dataset["Department"].fillna(dataset["Department"].mode()[0])
# Out:
# 0                   Marketing
# 1             Human Resources
# 2                  Operations
# 3                  Operations
# 4      Information Technology
#                 ...
# 995                 Marketing
# 996                Operations
# 997                 Marketing
# 998           Human Resources
# 999    Information Technology
# Name: Department, Length: 1000, dtype: object
